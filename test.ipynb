# %%
from datasets import load_dataset

dataset = load_dataset("fer2013")
print(dataset['train'])
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset("fer2013")
#       4 print(dataset['train'])
#
# File c:\Users\gbrlg\Documents\GitHub\face-to-emojis\myenv\Lib\site-packages\datasets\load.py:2132, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2127 verification_mode = VerificationMode(
#    2128     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2129 )
#    2131 # Create a dataset builder
# -> 2132 builder_instance = load_dataset_builder(
#    2133     path=path,
#    2134     name=name,
#    2135     data_dir=data_dir,
# ...

# %%
import tensorflow_datasets as tfds

dataset = tfds.load('fer2013', split='train',
                    as_supervised=True, download=True)
print(dataset)
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[5], line 3
#       1 import tensorflow_datasets as tfds
# ----> 3 dataset = tfds.load('fer2013', split='train', as_supervised=True, download=True)
#       4 print(dataset)
#
# File c:\Users\gbrlg\Documents\GitHub\face-to-emojis\myenv\Lib\site-packages\tensorflow_datasets\core\logging\__init__.py:176, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     174 metadata = self._start_call()
#     175 try:
# --> 176   return function(*args, **kwargs)
#     177 except Exception:
#     178   metadata.mark_error()
#
# ...
